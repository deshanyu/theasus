# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import matplotlib
matplotlib.style.use('ggplot')

# %%
file='clean_csv'
data=['TENURE','TOTALCHARGES','MONTHLYCHARGES', 'MONTHLY_MINUTES_OF_USE', 'TOTAL_MINUTES_OF_USE', 'MONTHLY_SMS',
       'TOTAL_SMS']

# %%
telecome_data=pd.read_csv(file,usecols=data )
#telecome_data.plot(kind='hist',subplots=True,range=(0,150),bins=100,figsize=(10,10))
                      # Set figure size

telecome_data.hist(bins=100,figsize=(20,20))
plt.show()
